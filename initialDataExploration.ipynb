# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = 12, 8

# %%
btc = pd.read_csv('gemini_BTCUSD_1hr.csv', skiprows=[0])
btc
# Out:
#        Unix Timestamp                 Date  Symbol      Open      High  \
# 0       1632960000000  2021-09-30 00:00:00  BTCUSD  41544.92  41573.17
# 1       1632956400000  2021-09-29 23:00:00  BTCUSD  41370.91  41554.64
# 2       1632952800000  2021-09-29 22:00:00  BTCUSD  41240.19  41461.98
# 3       1632949200000  2021-09-29 21:00:00  BTCUSD  41129.26  41293.52
# 4       1632945600000  2021-09-29 20:00:00  BTCUSD  41183.94  41247.73
# ...               ...                  ...     ...       ...       ...
# 52396      1444323600  2015-10-08 17:00:00  BTCUSD    244.25    244.99
# 52397      1444320000  2015-10-08 16:00:00  BTCUSD    244.92    244.92
# 52398      1444316400  2015-10-08 15:00:00  BTCUSD    245.00    245.00
# 52399      1444312800  2015-10-08 14:00:00  BTCUSD    245.00    245.00
# 52400      1444309200  2015-10-08 13:00:00  BTCUSD      0.00    245.00
#
#             Low     Close     Volume
# 0      41419.34  41443.92   2.998306
# 1      41309.07  41544.92  21.715405
# ...

# %%
eth = pd.read_csv('gemini_ETHUSD_1hr.csv', skiprows=[0])
eth
# Out:
#        Unix Timestamp                 Date  Symbol     Open     High      Low  \
# 0       1632960000000  2021-09-30 00:00:00  ETHUSD  2850.33  2855.87  2838.30
# 1       1632956400000  2021-09-29 23:00:00  ETHUSD  2837.20  2854.01  2831.98
# 2       1632952800000  2021-09-29 22:00:00  ETHUSD  2822.74  2845.14  2814.00
# 3       1632949200000  2021-09-29 21:00:00  ETHUSD  2821.76  2832.56  2806.03
# 4       1632945600000  2021-09-29 20:00:00  ETHUSD  2809.44  2825.86  2783.00
# ...               ...                  ...     ...      ...      ...      ...
# 47260      1462813200  2016-05-09 17:00:00  ETHUSD     9.83     9.83     9.48
# 47261      1462809600  2016-05-09 16:00:00  ETHUSD     9.99     9.99     9.79
# 47262      1462806000  2016-05-09 15:00:00  ETHUSD    10.00    10.00     9.99
# 47263      1462802400  2016-05-09 14:00:00  ETHUSD     9.55    10.00     9.55
# 47264      1462798800  2016-05-09 13:00:00  ETHUSD     0.00    12.00     0.00
#
#          Close       Volume
# ...

# %%
ltc = pd.read_csv('gemini_LTCUSD_1hr.csv', skiprows=[0])
ltc
# Out:
#        Unix Timestamp                 Date  Symbol    Open    High     Low  \
# 0       1632960000000  2021-09-30 00:00:00  LTCUSD  144.88  144.88  143.99
# 1       1632956400000  2021-09-29 23:00:00  LTCUSD  144.06  144.88  143.87
# 2       1632952800000  2021-09-29 22:00:00  LTCUSD  143.90  144.37  143.26
# 3       1632949200000  2021-09-29 21:00:00  LTCUSD  143.51  144.10  143.25
# 4       1632945600000  2021-09-29 20:00:00  LTCUSD  144.53  144.61  142.64
# ...               ...                  ...     ...     ...     ...     ...
# 25899   1539709200000  2018-10-16 17:00:00  LTCUSD   52.88   53.01   52.77
# 25900   1539705600000  2018-10-16 16:00:00  LTCUSD   53.67   53.67   52.83
# 25901   1539702000000  2018-10-16 15:00:00  LTCUSD   53.84   54.00   53.59
# 25902   1539698400000  2018-10-16 14:00:00  LTCUSD   54.60   54.69   53.84
# 25903   1539694800000  2018-10-16 13:00:00  LTCUSD    0.00   55.20    0.00
#
#         Close       Volume
# 0      143.99   302.539670
# ...

# %%
btc.plot(subplots=True)

plt.tight_layout()
plt.show()

# %%
plt.rcParams.update({'font.size': 18})

eth.plot(x='Date', y=['Unix Timestamp', 'Low', 'Volume'], subplots=True, logy=False, rot=18)

plt.tight_layout()
plt.show()

# %%
ltc.plot(subplots=True)

plt.tight_layout()
plt.show()

# %%
eth.Volume
# Out:
# 0          84.927589
# 1         261.015938
# 2         810.954428
# 3         733.644353
# 4        1449.435404
#             ...
# 47260     329.553213
# 47261      62.379450
# 47262      10.973567
# 47263     235.774075
# 47264     432.562115
# Name: Volume, Length: 47265, dtype: float64

# %%
eth.loc[eth.Volume == eth.Volume.max()]
# Out:
#        Unix Timestamp                 Date  Symbol   Open   High    Low  \
# 40469      1487260800  2017-02-16 16:00:00  ETHUSD  12.93  12.93  12.79
#
#        Close       Volume
# 40469  12.85  903102.6857
